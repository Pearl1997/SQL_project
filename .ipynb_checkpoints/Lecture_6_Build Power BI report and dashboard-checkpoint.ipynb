# %% [markdown]
# # Lecture 6 - Build Power BI report and dashboard

# %% [markdown]
# 1. Recap of SQL mock test
# 2. Building Power BI interactive report
# 3. Introducing advanced Power BI visualisations

# %% [markdown]
# ### Visualisation with Power BI

# %% [markdown]
# #### Set up Power BI

# %% [markdown]
# Set up your log in account with non-personal account

# %% [markdown]
# https://powerbi.microsoft.com/en-us/landing/signin/

# %% [markdown]
# For windows system, can download Power BI app for more functionalities

# %% [markdown]
# ![Powerbi.PNG](attachment:Powerbi.PNG)

# %% [markdown]
# #### Power BI Building Blocks

# %% [markdown]
# The fundamental Power BI building block are:
#
# * Visualizations
# * Datasets
# * Reports
# * Dashboards
# * Tiles

# %% [markdown]
# #### Power BI vs Tableau

# %% [markdown]
# ![powervstab.PNG](attachment:powervstab.PNG)

# %% [markdown]
# #### Key elements of Power BI report development

# %% [markdown]
# ##### Get data

# %% [markdown]
# * Import files from folder
# * Import files from database (desktop)
# * From a lot of other sources (desktop)

# %% [markdown]
# ##### Data and relationship

# %% [markdown]
# * View data
# * Data model - relationship between tables

# %% [markdown]
# ##### Manipulate columns and measures

# %% [markdown]
# * Create a new column
# * Create a mew measure

# %% [markdown]
# ##### Report formatting (desktop)

# %% [markdown]
# Template, background, layout, etc.

# %% [markdown]
# ##### Filter

# %% [markdown]
# Control the filters applied on single/all pages

# %% [markdown]
# ##### Slicer

# %% [markdown]
# Add slicer to select range of values

# %% [markdown]
# ##### Use proper charts

# %% [markdown]
# Demo - visualisation charts

# %% [markdown]
# ##### Formatting

# %% [markdown]
# chart attributes including size, color, layout, etc.

# %% [markdown]
# ##### Text box, shapes and buttons

# %% [markdown]
# Demo - usage

# %% [markdown]
# ##### Report and dashboard

# %% [markdown]
# Collate report results to build dashboard

# %% [markdown]
# #### Practise

# %% [markdown]
# 1. UK customers
# 2. Global Covid-19 status report
# 3. Tesla stock price
